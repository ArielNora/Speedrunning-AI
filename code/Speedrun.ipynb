# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

from logger import MetricLogger
from agent import Mario
import pygame, sys
from game import Game
from gymEnv import MarioEnv
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
useAgent = True
nbActions=3
pygame.init()
env = MarioEnv(useAgent,nbActions,levelnumber=1)

# %%
useAgent = True
nbActions=3
pygame.init()
env = MarioEnv(useAgent,nbActions,levelnumber=1)

use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

mario = Mario(state_dim=(1, 84, 84), action_dim=env.action_space.n)

logger = MetricLogger()    
        
episodes = 300
for e in range(episodes):

    state = env.reset()
    test = state.shape
    #print()
    # Play the game!
    while True:
        
        #print(state.shape,end="    ")
        # Run agent on the state
        action = mario.act(state)
        # Agent performs action
        next_state, reward, done, info = env.step(action)
        # Remember
        mario.cache(state, next_state, action, reward, done)

        # Learn
        q, loss = mario.learn()

        # Logging
        logger.log_step(reward, loss, q)

        # Update state
        state = next_state
        env.render()
        pygame.display.update()
        # Check if end of game
        if done:
            break

    logger.log_episode()
    if e % 10 == 0:
        logger.record(episode=e, epsilon=mario.exploration_rate, step=mario.curr_step)
    
pygame.quit()
# Out:
# Using CUDA: False
#
# Episode 0 - Step 57 - Epsilon 0.9805237679540135 - Mean Reward 772583.789 - Mean Length 57.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 2.068 - Time 2022-03-22T03:12:49
# Episode 10 - Step 493 - Epsilon 0.8435683520666404 - Mean Reward 607900.766 - Mean Length 44.818 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 18.014 - Time 2022-03-22T03:13:07
# Episode 20 - Step 976 - Epsilon 0.7140672755921728 - Mean Reward 634474.366 - Mean Length 46.476 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 18.539 - Time 2022-03-22T03:13:26
# Episode 30 - Step 1421 - Epsilon 0.6124245139321118 - Mean Reward 627803.624 - Mean Length 45.839 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 18.324 - Time 2022-03-22T03:13:44
# Episode 40 - Step 1861 - Epsilon 0.5261569228920633 - Mean Reward 623748.356 - Mean Length 45.39 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 20.005 - Time 2022-03-22T03:14:04
# Episode 50 - Step 2245 - Epsilon 0.4608610753921049 - Mean Reward 605825.828 - Mean Length 44.02 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 18.882 - Time 2022-03-22T03:14:23
# Episode 60 - Step 2727 - Epsilon 0.39024625036430205 - Mean Reward 616654.125 - Mean Length 44.705 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 21.901 - Time 2022-03-22T03:14:45
# Episode 70 - Step 3157 - Epsilon 0.3364341216712376 - Mean Reward 614437.326 - Mean Length 44.465 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 19.604 - Time 2022-03-22T03:15:04
# Episode 80 - Step 3442 - Epsilon 0.304923336669716 - Mean Reward 587025.34 - Mean Length 42.494 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 14.314 - Time 2022-03-22T03:15:19
# Episode 90 - Step 3672 - Epsilon 0.2816588815408398 - Mean Reward 556880.951 - Mean Length 40.352 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 12.793 - Time 2022-03-22T03:15:31
# Episode 100 - Step 4006 - Epsilon 0.2509984633644754 - Mean Reward 545119.415 - Mean Length 39.49 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 15.975 - Time 2022-03-22T03:15:47
# Episode 110 - Step 4389 - Epsilon 0.21992553648330063 - Mean Reward 539162.321 - Mean Length 38.96 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 19.596 - Time 2022-03-22T03:16:07
# Episode 120 - Step 4634 - Epsilon 0.20209733435927257 - Mean Reward 506430.095 - Mean Length 36.58 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 12.783 - Time 2022-03-22T03:16:20
# Episode 130 - Step 4865 - Epsilon 0.1866136961304275 - Mean Reward 476392.004 - Mean Length 34.44 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta

plt.xlabel("Episode")
plt.ylabel("Reward")
plt.show()
plt.plot(np.array(range(30))*10,logger.moving_avg_ep_lengths)
plt.title("Average length")
plt.xlabel("Episode")
plt.ylabel("Length")
plt.show()

# %% [markdown]
# The average reward shows that the agent gets consistently closer and closer to the goal, or even touches the goal.
# The average length shows that the agent goes further into the level without dieing, the peak shows that it overshoots and dies after the goal but it diminishes and stops on the goal.

# %% [markdown]
# #### Precision level

# %% [markdown]
# On this level, the agent needs to jump and stop moving during the jump to reduce the length of the jump and land on the platforms

# %%
pygame.init()
useAgent = True
nbActions=3
pygame.init()
env = MarioEnv(useAgent,nbActions,levelnumber=2)

use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

mario = Mario(state_dim=(1, 84, 84), action_dim=env.action_space.n)

logger = MetricLogger()    
        
episodes = 400
for e in range(episodes):

    state = env.reset()
    test = state.shape
    #print()
    # Play the game!
    while True:
        
        #print(state.shape,end="    ")
        # Run agent on the state
        action = mario.act(state)
        # Agent performs action
        next_state, reward, done, info = env.step(action)
        # Remember
        mario.cache(state, next_state, action, reward, done)

        # Learn
        q, loss = mario.learn()

        # Logging
        logger.log_step(reward, loss, q)

        # Update state
        state = next_state
        env.render()
        pygame.display.update()
        # Check if end of game
        if done:
            break

    logger.log_episode()
    if e % 10 == 0:
        logger.record(episode=e, epsilon=mario.exploration_rate, step=mario.curr_step)
    
pygame.quit()
# Out:
# Using CUDA: False
#
# Episode 0 - Step 29 - Epsilon 0.9900431744394126 - Mean Reward 400476.001 - Mean Length 29.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 1.1 - Time 2022-03-22T03:45:05
# Episode 10 - Step 384 - Epsilon 0.875900430728814 - Mean Reward 471572.522 - Mean Length 34.909 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 13.113 - Time 2022-03-22T03:45:18
# Episode 20 - Step 803 - Epsilon 0.7579917331515647 - Mean Reward 519651.162 - Mean Length 38.238 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 16.687 - Time 2022-03-22T03:45:35
# Episode 30 - Step 1087 - Epsilon 0.6872345006026239 - Mean Reward 476785.129 - Mean Length 35.065 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 12.591 - Time 2022-03-22T03:45:47
# Episode 40 - Step 1406 - Epsilon 0.6156025751785197 - Mean Reward 466783.865 - Mean Length 34.293 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 14.485 - Time 2022-03-22T03:46:02
# Episode 50 - Step 1781 - Epsilon 0.5408836888426999 - Mean Reward 476642.756 - Mean Length 34.922 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 14.779 - Time 2022-03-22T03:46:16
# Episode 60 - Step 2182 - Epsilon 0.4709893078636801 - Mean Reward 490162.522 - Mean Length 35.77 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 15.711 - Time 2022-03-22T03:46:32
# Episode 70 - Step 2518 - Epsilon 0.41942947376843887 - Mean Reward 486169.932 - Mean Length 35.465 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 13.855 - Time 2022-03-22T03:46:46
# Episode 80 - Step 2891 - Epsilon 0.36877554829379555 - Mean Reward 489862.988 - Mean Length 35.691 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 15.241 - Time 2022-03-22T03:47:01
# Episode 90 - Step 3159 - Epsilon 0.33620202217135575 - Mean Reward 476587.428 - Mean Length 34.714 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta
# Episode 270 - Step 8290 - Epsilon 0.1 - Mean Reward 395587.539 - Mean Length 28.61 - Mean Loss 457.239 - Mean Q Value 14072.336 - Time Delta 17.205 - Time 2022-03-22T03:52:40
# Episode 280 - Step 8527 - Epsilon 0.1 - Mean Reward 383370.002 - Mean Length 27.78 - Mean Loss 453.508 - Mean Q Value 14075.153 - Time Delta 16.934 - Time 2022-03-22T03:52:57
# Episode 290 - Step 8866 - Epsilon 0.1 - Mean Reward 393567.954 - Mean Length 28.51 - Mean Loss 461.349 - Mean Q Value 14075.883 - Time Delta 22.621 - Time 2022-03-22T03:53:20
# Episode 300 - Step 9147 - Epsilon 0.1 - Mean Reward 391297.698 - Mean Length 28.31 - Mean Loss 465.981 - Mean Q Value 14078.328 - Time Delta 20.239 - Time 2022-03-22T03:53:40
# Episode 310 - Step 9389 - Epsilon 0.1 - Mean Reward 380392.733 - Mean Length 27.53 - Mean Loss 470.898 - Mean Q Value 14079.906 - Time Delta 17.365 - Time 2022-03-22T03:53:57
# Episode 320 - Step 9667 - Epsilon 0.1 - Mean Reward 381363.352 - Mean Length 27.62 - Mean Loss 464.424 - Mean Q Value 14081.889 - Time Delta 19.191 - Time 2022-03-22T03:54:17
# Episode 330 - Step 9978 - Epsilon 0.1 - Mean Reward 381349.344 - Mean Length 27.64 - Mean Loss 468.71 - Mean Q Value 14083.448 - Time Delta 24.83 - Time 2022-03-22T03:54:41
# Episode 340 - Step 10258 - Epsilon 0.1 - Mean Reward 380782.711 - Mean Length 27.66 - Mean Loss 699.391 - Mean Q Value 15139.406 - Time Delta 24.15 - Time 2022-03-22T03:55:06
# Episode 350 - Step 10559 - Epsilon 0.1 - Mean Reward 387313.27 - Mean Length 28.15 - Mean Loss 759.645 - Mean Q Value 16407.204 - Time Delta 25.816 - Time 2022-03-22T03:55:31
# Episode 360 - Step 10833 - Epsilon 0.1 - Mean Reward 385570.281 - Mean Length 28.06 - Mean Loss 807.259 - Mean Q Value 17679.821 - Time Delta 24.316 - Time 2022-03-22T03:55:56
# Episode 370 - Step 11102 - Epsilon 0.1 - Mean Reward 386691.571 - Mean Length 28.12 - Mean Loss 852.548 - Mean Q Value 18952.994 - Time Delta 25.425 - Time 2022-03-22T03:56:21
# Episode 380 - Step 11425 - Epsilon 0.1 - Mean Reward 398806.21 - Mean Length 28.98 - Mean Loss 903.444 - Mean Q Value 20222.087 - Time Delta 32.874 - Time 2022-03-22T03:56:54
# Episode 390 - Step 11688 - Epsilon 0.1 - Mean Reward 387673.168 - Mean Length 28.22 - Mean Loss 958.257 - Mean Q Value 21491.462 - Time Delta 26.977 - Time 2022-03-22T03:57:21

# %%
plt.plot(np.array(range(int(episodes/10)))*10,logger.moving_avg_ep_rewards)
plt.title("Average reward")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.show()
plt.plot(np.array(range(int(episodes/10)))*10,logger.moving_avg_ep_lengths)
plt.title("Average length")
plt.xlabel("Episode")
plt.ylabel("Length")
plt.show()

# %% [markdown]
# The model has troubles with the precision level.

# %% [markdown]
# #### Button Level

# %% [markdown]
# This level has a platform with a button that needs to be pushed to access the end

# %%
pygame.init()
useAgent = True
nbActions=3
pygame.init()
env = MarioEnv(useAgent,nbActions,levelnumber=3)

use_cuda = torch.cuda.is_available()
print(f"Using CUDA: {use_cuda}")
print()

mario = Mario(state_dim=(1, 84, 84), action_dim=env.action_space.n,lrd=0.999975)

logger = MetricLogger()    
        
episodes = 300
for e in range(episodes):

    state = env.reset()
    test = state.shape
    #print()
    # Play the game!
    while True:
        
        #print(state.shape,end="    ")
        # Run agent on the state
        action = mario.act(state)
        # Agent performs action
        next_state, reward, done, info = env.step(action)
        # Remember
        mario.cache(state, next_state, action, reward, done)

        # Learn
        q, loss = mario.learn()

        # Logging
        logger.log_step(reward, loss, q)

        # Update state
        state = next_state
        env.render()
        pygame.display.update()
        # Check if end of game
        if done:
            break

    logger.log_episode()
    if e % 10 == 0:
        logger.record(episode=e, epsilon=mario.exploration_rate, step=mario.curr_step)
    
pygame.quit()
# Out:
# Using CUDA: False
#
# Episode 0 - Step 144 - Epsilon 0.9964064273919485 - Mean Reward 1956935.504 - Mean Length 144.0 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 7.138 -
# Episode 10 - Step 1085 - Epsilon 0.9732392489786711 - Mean Reward 1350346.18 - Mean Length 98.636 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 31.827 -
# Episode 20 - Step 2050 - Epsilon 0.9500405219283775 - Mean Reward 1338821.8 - Mean Length 97.619 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 34.995 -
# Episode 30 - Step 3428 - Epsilon 0.9178685675016021 - Mean Reward 1480639.845 - Mean Length 110.581 - Mean Loss 0.0 - Mean Q Value 0.0 - Time Delta 49.107 -
# Episode 40 - Step 5229 - Epsilon 0.877457608605954 - Mean Reward 1674271.319 - Mean Length 127.537 - Mean Loss 476.85 - Mean Q Value 193.808 - Time Delta 72.298 -
# Episode 50 - Step 6477 - Epsilon 0.8505032685200001 - Mean Reward 1670005.556 - Mean Length 127.0 - Mean Loss 563.505 - Mean Q Value 2833.613 - Time Delta 75.713 -
# Episode 60 - Step 7562 - Epsilon 0.8277431623083095 - Mean Reward 1634431.064 - Mean Length 123.967 - Mean Loss 604.142 - Mean Q Value 4609.646 - Time Delta 74.674 -
# Episode 70 - Step 9502 - Epsilon 0.7885551205634934 - Mean Reward 1746024.747 - Mean Length 133.831 - Mean Loss 632.563 - Mean Q Value 5875.171 - Time Delta 133.667 -
# Episode 80 - Step 11112 - Epsilon 0.757445665746656 - Mean Reward 1782883.381 - Mean Length 137.185 - Mean Loss 690.228 - Mean Q Value 7657.586 - Time Delta 110.24 -
# Episode 90 - Step 12109 - Epsilon 0.7387994433371945 - Mean Reward 1732628.508 - Mean Length 133.066 - Mean Loss 696.515 - Mean Q Value 9570.466 - Time Delta 70.829 -
# Episode 100 - Step 13294 - Epsilon 0.7172332665201078 - Mean Reward 1711683.439 - Mean Length 131.5 - Mean Loss 708.069 - Mean Q Value 11219.364 - Time Delta 75.361 -
# Episode 110 - Step 14709 - Epsilon 0.692304357805633 - Mean Reward 1764150.323 - Mean Length 136.24 - Mean Loss 784.182 - Mean Q Value 13724.766 - Time Delta 86.97 -
# Episode 120 - Step 16019 - Epsilon 0.669998365587474 - Mean Reward 1803784.176 - Mean Length 139.69 - Mean Loss 896.019 - Mean Q Value 17012.172 - Time Delta 80.008 -
# Episode 130 - Step 17279 - Epsilon 0.6492221014574925 - Mean Reward 1791403.238 - Mean Length 138.51 - Mean Loss 981.361 - Mean Q Value 20568.437 - Time Delta 77.559 -
# Episode 140 - Step 18736 - Epsilon 0.6259994070427293 - Mean Reward 1751217.842 - Mean Length 135.07 - Mean Loss 872.952 - Mean Q Value 24044.126 - Time Delta 93.615 -
# Episode 150 - Step 20034 - Epsilon 0.606011533612298 - Mean Reward 1756372.798 - Mean Length 135.57 - Mean Loss 880.812 - Mean Q Value 26251.449 - Time Delta 85.329 -
# Episode 160 - Step 21024 - Epsilon 0.5911966533666976 - Mean Reward 1743325.877 - Mean Length 134.62 - Mean Loss 908.776 - Mean Q Value 29399.259 - Time Delta 61.704 -
# Episode 170 - Step 22435 - Epsilon 0.5707054732583549 - Mean Reward 1681799.536 - Mean Length 129.33 - Mean Loss 921.163 - Mean Q Value 32555.808 - Time Delta 86.95 -
# Episode 180 - Step 23417 - Epsilon 0.5568650670097297 - Mean Reward 1608745.04 - Mean Length 123.05 - Mean Loss 909.292 - Mean Q Value 35046.478 - Time Delta 59.705 -
# Episode 190 - Step 24853 - Epsilon 0.5372279607197322 - Mean Reward 1662906.235 - Mean Length 127.44 - Mean Loss 936.792 - Mean Q Value 37056.525 - Time Delta 85.708 -
# Episode 200 - Step 26173 - Epsilon 0.5197885528692905 - Mean Reward 1681981.819 - Mean Length 128.79 - Mean Loss 984.991 - Mean Q Value 39873.213 - Time Delta 79.219 -
# Episode 210 - Step 27480 - Epsilon 0.5030787363444102 - Mean Reward 1672935.935 - Mean Length 127.71 - Mean Loss 1015.414 - Mean Q Value 42745.485 - Time Delta 79.428 -
# Episode 220 - Step 28955 - Epsilon 0.4848653533294779 - Mean Reward 1690699.553 - Mean Length 129.36 - Mean Loss 1002.372 - Mean Q Value 44834.312 - Time Delta 87.909 -
# Episode 230 - Step 29963 - Epsilon 0.4727992668272891 - Mean Reward 1660708.599 - Mean Length 126.84 - Mean Loss 1030.944 - Mean Q Value 46661.847 - Time Delta 61.559 -
# Episode 240 - Step 31552 - Epsilon 0.4543852555995512 - Mean Reward 1676789.557 - Mean Length 128.16 - Mean Loss 1063.477 - Mean Q Value 49237.621 - Time Delta 95.354 -
# Episode 250 - Step 32728 - Epsilon 0.4412206327286066 - Mean Reward 1663156.786 - Mean Length 126.94 - Mean Loss 1076.967 - Mean Q Value 51797.977 - Time Delta 72.271 -
# Episode 260 - Step 33673 - Epsilon 0.43091883564128636 - Mean Reward 1658870.856 - Mean Length 126.49 - Mean Loss 1086.419 - Mean Q Value 53434.128 - Time Delta 58.044 -
# Episode 270 - Step 34906 - Epsilon 0.41783823945385384 - Mean Reward 1638543.875 - Mean Length 124.71 - Mean Loss 1110.04 - Mean Q Value 55074.965 - Time Delta 75.72 -
# Episode 280 - Step 36477 - Epsilon 0.40174553060033974 - Mean Reward 1706804.212 - Mean Length 130.6 - Mean Loss 1155.844 - Mean Q Value 57342.874 - Time Delta 95.916 -
# Episode 290 - Step 37744 - Epsilon 0.38921951243629294 - Mean Reward 1686253.595 - Mean Length 128.91 - Mean Loss 1177.91 - Mean Q Value 59653.593 - Time Delta 82.395 -

# %%
plt.plot(np.array(range(int(episodes/10)))*10,logger.moving_avg_ep_rewards)
plt.title("Average reward")
plt.xlabel("Episode")
plt.ylabel("Reward")
plt.show()
plt.plot(np.array(range(int(episodes/10)))*10,logger.moving_avg_ep_lengths)
plt.title("Average length")
plt.xlabel("Episode")
plt.ylabel("Length")
plt.show()
